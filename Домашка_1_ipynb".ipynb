# %% [markdown]
# <a href="https://colab.research.google.com/github/irina120186/hexal/blob/master/%D0%94%D0%BE%D0%BC%D0%B0%D1%88%D0%BA%D0%B0_1_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Великая первая домашка

# %% [markdown]
# ![science_dog.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# С клавиатуры вводится число, ваша задача вывести его остаток от деления на 2 следующим образом:
#
# Ввод: 2
#
# Вывод: остаток от деления 2 на 2 = 0

# %%
a = int(input())
a % 2

# %% [markdown]
# Используя индексы, соберите из слова  "кардиолог" слово рогалик и выведите его на экран

# %%
word = "кардиолог"

# %% [markdown]
# Пользователь вводит с клавиатуры три слога, ваша задача сложить их в слово в обратном порядке и вывести на экран
#
# Пример.
#
# Ввод:
# ко
# ло
# мо
#
# Вывод: молоко

# %% [markdown]
# Напишите код, который просит пользователя ввести возраст, имя, пол. После чего формирует следующий вывод на экране
#
# ****Анкета клиента****
# Имя: имя
# Возраст: возраст
# Пол: пол
#
# Если можете уместить это в один print (помните, про то, что \n переносит строку, будет еще круче)
